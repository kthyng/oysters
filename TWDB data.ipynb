# %%
# %matplotlib inline
import pandas as pd
import tabs

# %%
df = tabs.read('DOLLAR', '1987-1-1', '2001-1-1')
df = df.join(tabs.read('EAST', '1990-1-1', '2000-1-1'), how='outer')

# %%
df[['DOLLAR: Salinity', 'EAST: Salinity']].plot(figsize=(15,5), alpha=0.5)
